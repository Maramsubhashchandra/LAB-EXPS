# %% [markdown]
# <a href="https://colab.research.google.com/github/Maramsubhashchandra/LAB-EXPS/blob/main/EXP16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python program to implement BFS

from collections import deque

# Graph represented using a dictionary
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}


def bfs(graph, start):
    visited = set()
    queue = deque()

    # Start from the given node
    visited.add(start)
    queue.append(start)

    print("BFS Traversal:")

    while queue:
        # Remove the first element from queue
        node = queue.popleft()
        print(node, end=" ")

        # Visit all adjacent nodes
        for neighbour in graph[node]:
            if neighbour not in visited:
                visited.add(neighbour)
                queue.append(neighbour)


# Call BFS
bfs(graph, 'A')
# Out:
# BFS Traversal:
# A B C D E F
