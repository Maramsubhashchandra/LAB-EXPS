# %% [markdown]
# <a href="https://colab.research.google.com/github/Maramsubhashchandra/LAB-EXPS/blob/main/EXP27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install -y swi-prolog
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swi-prolog is already the newest version (8.4.2+dfsg-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
# %%writefile database.pl
#
# % Database containing Name and Date of Birth
#
# person(rahul, '10-05-2000').
# person(priya, '15-08-2001').
# person(amit, '22-01-1999').
# person(neha, '30-12-2002').
# person(rohan, '05-03-2000').
#
# % Find date of birth using name
# find_dob(Name, DOB) :-
#     person(Name, DOB).
# Out:
# Writing database.pl

# %%
# !swipl -q -s database.pl -g "find_dob(priya,DOB),write('DOB of Priya = '),write(DOB),nl,halt."
# Out:
# DOB of Priya = 15-08-2001
