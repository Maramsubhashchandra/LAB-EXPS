# %% [markdown]
# <a href="https://colab.research.google.com/github/Maramsubhashchandra/LAB-EXPS/blob/main/EXP25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python program to implement Feed Forward Neural Network

from sklearn.neural_network import MLPClassifier

# Input data
# Example: [Study Hours, Attendance]
X = [
    [1, 50],
    [2, 55],
    [3, 60],
    [4, 65],
    [5, 70],
    [6, 75],
    [7, 80],
    [8, 85]
]

# Target output
# 0 = Fail, 1 = Pass
y = [0, 0, 0, 0, 1, 1, 1, 1]

# Create Feed Forward Neural Network
model = MLPClassifier(
    hidden_layer_sizes=(5,),
    activation='relu',
    solver='lbfgs',
    max_iter=1000,
    random_state=1
)

# Train the neural network
model.fit(X, y)

# Get input from user
hours = float(input("Enter study hours: "))
attendance = float(input("Enter attendance percentage: "))

# Predict the result
prediction = model.predict([[hours, attendance]])

# Display result
if prediction[0] == 1:
    print("Prediction: PASS")
else:
    print("Prediction: FAIL")
# Out:
# Enter study hours: 7
# Enter attendance percentage: 80
# Prediction: PASS
