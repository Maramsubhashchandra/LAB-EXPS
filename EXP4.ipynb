# %% [markdown]
# <a href="https://colab.research.google.com/github/Maramsubhashchandra/LAB-EXPS/blob/main/EXP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to sort a sentence in alphabetical order

sentence = input("Enter a sentence: ")

# Split the sentence into words
words = sentence.split()

# Sort the words alphabetically
words.sort()

# Display the sorted sentence
print("Sentence in alphabetical order:")
print(" ".join(words))
# Out:
# Enter a sentence: PYTHON IS EASY TO LEARN
# Sentence in alphabetical order:
# EASY IS LEARN PYTHON TO
