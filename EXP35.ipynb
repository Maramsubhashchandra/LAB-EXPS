# %% [markdown]
# <a href="https://colab.research.google.com/github/Maramsubhashchandra/LAB-EXPS/blob/main/EXP35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install -y swi-prolog
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swi-prolog is already the newest version (8.4.2+dfsg-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
# %%writefile fruit.pl
#
# % Fruit and its color
#
# fruit_color(apple, red).
# fruit_color(apple, green).
# fruit_color(banana, yellow).
# fruit_color(orange, orange).
# fruit_color(grapes, green).
# fruit_color(grapes, purple).
# fruit_color(mango, yellow).
# fruit_color(mango, green).
#
# % Display fruit and color
# show_fruit(Fruit) :-
#     fruit_color(Fruit, Color),
#     write(Fruit),
#     write(' is '),
#     write(Color),
#     nl,
#     fail.
#
# show_fruit(_).
# Out:
# Writing fruit.pl

# %%
# !swipl -q -s fruit.pl -g "show_fruit(apple),halt."
# Out:
# apple is red
# apple is green
